# %%
# Eval on same base model, direct strategy, and different input and output types

# %%
import pandas as pd
from pathlib import Path

# %%
## Project root path
pjpath = ''

# Hacky way of finding the project's root path. Do not rely on this, set your own pjpath!
for p in Path.cwd().parents:
    if p.stem == 'llms4mortality':
        pjpath = p
        break

print(f'> Project path is {pjpath}')
# Out:
# > Project path is /home/daucco/Syncthing/Dev/papers/llms4mortality

# %%
# Relevant paths
mimicpath = pjpath / 'data/mimiciv'

# %%
# Globals

SEED = 42

# Controls which data to load
samp_size = 5000
balanced_data = True

base_models = [
    'llama3',
    'hf.co/QuantFactory/Llama3-Med42-8B-GGUF:Q8_0',
    'hf.co/DevQuasar/google.medgemma-4b-it-GGUF:Q8_0',

    # Extras
    'hf.co/cngchis/Llama3.1-medical-GGUF:Q5_K_M',
    #'hf.co/unsloth/gemma-4-E4B-it-GGUF:Q5_K_M',
    'hf.co/DevQuasar/nvidia.Qwen3-Nemotron-8B-BRRM-GGUF:Q5_K_M',
    #'hf.co/DevQuasar/Qwen.Qwen3-VL-8B-Instruct-GGUF:Q5_K_M',
    'hf.co/QuantFactory/ghost-8b-beta-GGUF:Q5_K_M',
    #'hf.co/DevQuasar/Qwen.Qwen3-VL-8B-Thinking-GGUF:Q5_K_M',
]

# Experiment configs to try to evaluate
input_type = ['S', 'R', 'RC']
output_type = ['M', 'PM']
num_ctx = [32] # (X 1024) LLM should behave better allowing bigger context. We cannot test anything above 32k due to GPU constraints
temperatures = [0.1, 0.7, 0.9] #[0.0, 0.1, 0.3, 0.7, 1.0]   # Temperature option for the LLM. The greater, the more creative the answer (def 0.1)

# %%
# Load precomputed dataframe. Keeps only hadm_id and delta_days_dod (to find patients that died after n days discharge)
# Transform to boolean (patient died within 30 days after discharge)
df = pd.read_csv(mimicpath / f'mimiciv_4_mortality_S{samp_size}{'_balanced' if balanced_data else ''}.csv.gz')

# Resolves deaths within a month
df['DIES'] = df['delta_days_dod'].apply(lambda x: x > 0 and x <= 30)

# %%
df.head()
# Out:
#     hadm_id         note_id  subject_id   charttime  \
# 0  21891113   19147811-DS-5    19147811  2148-09-22
# 1  29643114   15193172-DS-9    15193172  2129-06-28
# 2  26747385  16281465-DS-16    16281465  2144-08-25
# 3  23932127   15966914-DS-9    15966914  2155-04-26
# 4  27210508  15484986-DS-28    15484986  2167-11-21
#
#                                                 text gender         dod  \
# 0   \nName:  ___                Unit No:   ___\n ...      F  2149-04-22
# 1   \nName:  ___                    Unit No:   __...      M  2129-07-17
# 2   \nName:  ___           Unit No:   ___\n \nAdm...      F  2144-09-06
# 3   \nName:  ___                   Unit No:   ___...      M         NaN
# 4   \nName:  ___                  Unit No:   ___\...      M  2167-12-11
#
#    anchor_age  anchor_year   admittime  ... insurance marital_status   race  \
# 0          68         2148  2148-09-19  ...     Other       DIVORCED  WHITE
# ...

# %%
# Loads sysprompt definitions to fetch the qualified name of each approach
import json

sysprompt_in_fpath = pjpath / 'ollama/sysprompts/sysprompt_in.json'
sysprompt_out_fpath = pjpath / 'ollama/sysprompts/sysprompt_out.json'

with open(sysprompt_in_fpath, 'r') as ifile:
    sprompt_data_in = json.load(ifile)

with open(sysprompt_out_fpath, 'r') as ifile:
    sprompt_data_out = json.load(ifile)

sprompt_in_names = {i_type: sprompt_data_in[i_type]['name'] if 'name' in sprompt_data_in[i_type].keys() else i_type for i_type in input_type}
sprompt_out_names = {o_type: sprompt_data_out[o_type]['name'] if 'name' in sprompt_data_out[o_type].keys() else o_type for o_type in output_type}

# %%
# Load results

from sklearn.metrics import precision_recall_fscore_support as prf
from sklearn.metrics import matthews_corrcoef as mcc

results = []

#llm_exp_id = ['simple', 'cot1nn', 'cot1p1', 'cot1nn_wcourse', 'cot1p1_wcourse']
llm_exp_id = ['simple', 'cot1nn', 'cot1p1']
llm_exp_fpath = pjpath / f'exps/results/llms'

for lleid in llm_exp_id:
    for base_model in base_models:
        bmodel_name = base_model.replace('/', '').replace('.', '').replace(':', '_')
        for i_type in input_type:
            for o_type in output_type:
                for nctx in num_ctx:
                    for temp in temperatures:
                        fname = f'{bmodel_name}_{i_type}_{o_type}_{nctx}k_t{str(temp).replace('.', '')}'
                        fpath = llm_exp_fpath / f'{lleid}/{fname}.csv'

                        # Skips missing results
                        if not Path(fpath).is_file():
                            continue

                        df_res = pd.read_csv(fpath, index_col=0)

                        y_true = df.set_index('hadm_id').loc[df_res.index]['DIES']
                        y_pred = df_res.DIES.apply(lambda x: True if x =='YES' else False)

                        res_uf1 = prf(y_true, y_pred, average='micro')[2]
                        res_Mf1 = prf(y_true, y_pred, average='macro')[2]
                        res_mcc = mcc(y_true, y_pred)
                        
                        res = {
                            'LLM STRAT': lleid,
                            'BASE MODEL': base_model,
                            'INPUT_TYPE': sprompt_in_names[i_type],
                            'OUTPUT_TYPE': sprompt_out_names[o_type],
                            'num_ctx': nctx * 1024,
                            'temp': temp,
                            'uf1': res_uf1,
                            'Mf1': res_Mf1,
                            'mcc': res_mcc
                        }
                        results.append(res)

pd.DataFrame(results)
# Out:
#    LLM STRAT                                         BASE MODEL  \
# 0     simple                                             llama3
# 1     simple                                             llama3
# 2     simple                                             llama3
# 3     simple                                             llama3
# 4     simple                                             llama3
# 5     simple                                             llama3
# 6     simple       hf.co/QuantFactory/Llama3-Med42-8B-GGUF:Q8_0
# 7     simple       hf.co/QuantFactory/Llama3-Med42-8B-GGUF:Q8_0
# 8     simple       hf.co/QuantFactory/Llama3-Med42-8B-GGUF:Q8_0
# 9     simple       hf.co/QuantFactory/Llama3-Med42-8B-GGUF:Q8_0
# 10    simple    hf.co/DevQuasar/google.medgemma-4b-it-GGUF:Q8_0
# 11    simple    hf.co/DevQuasar/google.medgemma-4b-it-GGUF:Q8_0
# 12    simple    hf.co/DevQuasar/google.medgemma-4b-it-GGUF:Q8_0
# 13    simple    hf.co/DevQuasar/google.medgemma-4b-it-GGUF:Q8_0
# ...
